# %% [markdown]
# # AdaBoosting Classification Implimentation

# %% [markdown]
# **AdaBoost Classifier Implimentation**

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier, AdaBoostRegressor
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
X,y = make_classification(n_samples = 1000, n_features =20,n_classes=2,random_state=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=1)

# %%
classifier = AdaBoostClassifier()
classifier.fit(X_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
print("acc",accuracy_score(y_test,y_pred))
print("clf_report",classification_report(y_test,y_pred))
print("con_mat", confusion_matrix(y_test,y_pred))
# Out:
# acc 0.8393939393939394
# clf_report               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       154
#            1       0.86      0.84      0.85       176
#
#     accuracy                           0.84       330
#    macro avg       0.84      0.84      0.84       330
# weighted avg       0.84      0.84      0.84       330
#
# con_mat [[129  25]
#  [ 28 148]]

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {"n_estimators":[50,100,200],"learning_rate":[0.001,0.1,1,1.5,2,2.5],"algorithm":["SAMME.R","SAMME"]}

ada = AdaBoostClassifier()

clf = GridSearchCV(estimator=ada,param_grid=param_grid,cv=5,verbose=3)
clf
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(),
#              param_grid={'algorithm': ['SAMME.R', 'SAMME'],
#                          'learning_rate': [0.001, 0.1, 1, 1.5, 2, 2.5],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END algorithm=SAMME.R, learning_rate=0.001, n_estimators=100;, score=nan total time=   0.0s
# ...

# %%
clf.best_params_
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 0.1, 'n_estimators': 200}

# %%
clf.best_estimator_
# Out:
# AdaBoostClassifier(algorithm='SAMME', learning_rate=0.1, n_estimators=200)

# %%
clf.best_score_
# Out:
# 0.864179104477612

# %%
best_model = clf.best_estimator_
y_pred = best_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8424242424242424

# %% [markdown]
# # AdaBoosting Regression Implimentation

# %% [markdown]
# **AdaBoost Regression Implimentation**

# %%
# Adaboost Regressor

from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import r2_score

# %%
X,y = make_regression(n_samples=1000,n_features=20,n_informative=15,random_state=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=1)

# %%
reg = AdaBoostRegressor()
reg
# Out:
# AdaBoostRegressor()

# %%
reg.fit(X_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
y_pred = reg.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6617625073055515

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {"n_estimators":[50,100,200],"learning_rate":[0.001,0.1,1,1.5,2,2.5],"loss":["linear","square"]}

adr = AdaBoostRegressor()

reg = GridSearchCV(estimator=adr,param_grid=param_grid,cv=5,verbose=3)
reg
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [0.001, 0.1, 1, 1.5, 2, 2.5],
#                          'loss': ['linear', 'square'],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
reg.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END learning_rate=0.001, loss=linear, n_estimators=50;, score=0.450 total time=   0.3s
# [CV 2/5] END learning_rate=0.001, loss=linear, n_estimators=50;, score=0.403 total time=   0.3s
# [CV 3/5] END learning_rate=0.001, loss=linear, n_estimators=50;, score=0.418 total time=   0.3s
# [CV 4/5] END learning_rate=0.001, loss=linear, n_estimators=50;, score=0.427 total time=   0.3s
# [CV 5/5] END learning_rate=0.001, loss=linear, n_estimators=50;, score=0.400 total time=   0.3s
# [CV 1/5] END learning_rate=0.001, loss=linear, n_estimators=100;, score=0.428 total time=   0.6s
# [CV 2/5] END learning_rate=0.001, loss=linear, n_estimators=100;, score=0.431 total time=   0.6s
# [CV 3/5] END learning_rate=0.001, loss=linear, n_estimators=100;, score=0.474 total time=   0.6s
# [CV 4/5] END learning_rate=0.001, loss=linear, n_estimators=100;, score=0.442 total time=   0.6s
# ...

# %%
reg.best_params_
# Out:
# {'learning_rate': 1.5, 'loss': 'square', 'n_estimators': 200}

# %%
reg.best_score_
# Out:
# 0.7876804977452119

# %% [markdown]
# # Gradient Boosting Classification Implimentation

# %% [markdown]
# **Gradient Boosting Classification Implimentation**

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
X,y = make_classification(n_samples = 1000, n_features =20,n_classes=2,random_state=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=1)

# %%
classifier = GradientBoostingClassifier()
classifier.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = classifier.predict(X_test)
print("acc",accuracy_score(y_test,y_pred))
print("clf_report", classification_report(y_test,y_pred))
print("con_mat", confusion_matrix(y_test,y_pred))
# Out:
# acc 0.8636363636363636
# clf_report               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85       154
#            1       0.87      0.87      0.87       176
#
#     accuracy                           0.86       330
#    macro avg       0.86      0.86      0.86       330
# weighted avg       0.86      0.86      0.86       330
#
# con_mat [[132  22]
#  [ 23 153]]

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {"n_estimators":[50,100,200],"learning_rate":[0.001,0.1,1,1.5,2,2.5],"ccp_alpha":[1,2]}

gdc = GradientBoostingClassifier()

clf = GridSearchCV(estimator=gdc,param_grid=param_grid,cv=5,verbose=3)
clf
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'ccp_alpha': [1, 2],
#                          'learning_rate': [0.001, 0.1, 1, 1.5, 2, 2.5],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END ccp_alpha=1, learning_rate=0.001, n_estimators=50;, score=0.515 total time=   0.4s
# [CV 2/5] END ccp_alpha=1, learning_rate=0.001, n_estimators=50;, score=0.515 total time=   0.4s
# [CV 3/5] END ccp_alpha=1, learning_rate=0.001, n_estimators=50;, score=0.515 total time=   0.4s
# [CV 4/5] END ccp_alpha=1, learning_rate=0.001, n_estimators=50;, score=0.522 total time=   0.4s
# [CV 5/5] END ccp_alpha=1, learning_rate=0.001, n_estimators=50;, score=0.522 total time=   0.4s
# [CV 1/5] END ccp_alpha=1, learning_rate=0.001, n_estimators=100;, score=0.515 total time=   0.8s
# [CV 2/5] END ccp_alpha=1, learning_rate=0.001, n_estimators=100;, score=0.515 total time=   0.6s
# [CV 3/5] END ccp_alpha=1, learning_rate=0.001, n_estimators=100;, score=0.515 total time=   0.6s
# [CV 4/5] END ccp_alpha=1, learning_rate=0.001, n_estimators=100;, score=0.522 total time=   0.6s
# ...

# %%
clf.best_params_
# Out:
# {'ccp_alpha': 1, 'learning_rate': 0.001, 'n_estimators': 50}

# %%
clf.best_score_
# Out:
# 0.5179104477611941

# %%
best_model = clf.best_estimator_
y_pred = best_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4666666666666667

# %% [markdown]
# # Gradient Boosting Regression Implimentation

# %% [markdown]
# **Gradient Boosting Regression Implimentation**

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score

# %%
X,y = make_regression(n_samples = 1000, n_features =20,n_informative=20,random_state=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=1)

# %%
reg = GradientBoostingRegressor()
reg.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = reg.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7871136654598627

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {"n_estimators":[50,100,200],"learning_rate":[0.001,0.1,1,1.5,2,2.5],"loss":["squared_error",'huber']}

gdr = GradientBoostingRegressor()

reg = GridSearchCV(estimator=gdr,param_grid=param_grid,cv=5,verbose=3)
reg
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.001, 0.1, 1, 1.5, 2, 2.5],
#                          'loss': ['squared_error', 'huber'],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
reg.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END learning_rate=0.001, loss=squared_error, n_estimators=50;, score=0.019 total time=   0.5s
# [CV 2/5] END learning_rate=0.001, loss=squared_error, n_estimators=50;, score=-0.009 total time=   0.4s
# [CV 3/5] END learning_rate=0.001, loss=squared_error, n_estimators=50;, score=0.018 total time=   0.5s
# [CV 4/5] END learning_rate=0.001, loss=squared_error, n_estimators=50;, score=0.022 total time=   0.4s
# [CV 5/5] END learning_rate=0.001, loss=squared_error, n_estimators=50;, score=0.015 total time=   0.5s
# [CV 1/5] END learning_rate=0.001, loss=squared_error, n_estimators=100;, score=0.044 total time=   0.8s
# [CV 2/5] END learning_rate=0.001, loss=squared_error, n_estimators=100;, score=0.010 total time=   0.9s
# [CV 3/5] END learning_rate=0.001, loss=squared_error, n_estimators=100;, score=0.037 total time=   0.6s
# ...

# %%
reg.best_params_
# Out:
# {'learning_rate': 0.1, 'loss': 'squared_error', 'n_estimators': 200}

# %%
reg.best_score_
# Out:
# 0.7755030546082866

# %%
clf.best_params_
# Out:
# {'ccp_alpha': 1, 'learning_rate': 0.001, 'n_estimators': 50}

# %%
clf.best_score_
# Out:
# 0.5179104477611941

# %%
best_model = clf.best_estimator_
y_pred = best_model.predict(X_test)
